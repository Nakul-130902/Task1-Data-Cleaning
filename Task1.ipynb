# %% [markdown]
# 🔹 Step‑1: Load Dataset

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\ROYAL ENFIELD\OneDrive\Documents\Desktop\titles.csv")

# %%
df
# Out:
#              id                                      title   type  \
# 0      ts300399        Five Came Back: The Reference Films   SHOW
# 1       tm84618                                Taxi Driver  MOVIE
# 2      tm154986                                Deliverance  MOVIE
# 3      tm127384            Monty Python and the Holy Grail  MOVIE
# 4      tm120801                            The Dirty Dozen  MOVIE
# ...         ...                                        ...    ...
# 5845  tm1014599                                  Fine Wine  MOVIE
# 5846   tm898842                                C/O Kaadhal  MOVIE
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
# 5849   ts271048         Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# ...

# %% [markdown]
# 🔹 Step‑2: Missing Values Check

# %%
df.isnull().sum()
# Out:
# id                         0
# title                      1
# type                       0
# description               18
# release_year               0
# age_certification       2619
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 3744
# imdb_id                  403
# imdb_score               482
# imdb_votes               498
# tmdb_popularity           91
# tmdb_score               311
# dtype: int64

# %% [markdown]
# ✅ Step‑2 (part‑B): Handling Missing Values

# %%
df=df.dropna(subset=['title'])
df['description']=df['description'].fillna("No description available")
df['age_certification']=df['age_certification'].fillna("Unknown")
df['seasons']=df['seasons'].fillna(0)
df['imdb_id'] = df['imdb_id'].fillna("Unknown")
df['imdb_score']=df['imdb_score'].fillna(df['imdb_score'].median())
df['imdb_votes'] = df['imdb_votes'].fillna(df['imdb_votes'].median())
df['tmdb_popularity'] = df['tmdb_popularity'].fillna(df['tmdb_popularity'].median())
df['tmdb_score'] = df['tmdb_score'].fillna(df['tmdb_score'].median())

# %%
df.isnull().sum()
# Out:
# id                      0
# title                   0
# type                    0
# description             0
# release_year            0
# age_certification       0
# runtime                 0
# genres                  0
# production_countries    0
# seasons                 0
# imdb_id                 0
# imdb_score              0
# imdb_votes              0
# tmdb_popularity         0
# tmdb_score              0
# dtype: int64

# %% [markdown]
# ✅ Step‑3: Remove Duplicates

# %%
# Count duplicates

print("Duplicate_rows:",df.duplicated().sum())
# Out:
# Duplicate_rows: 0

# %% [markdown]
# Step‑4: Standardize Text Columns

# %%
df['title']=df['title'].str.strip().str.title()

# %%
df['genres'] = df['genres'].str.lower()
df['production_countries'] = df['production_countries'].str.title()

# %%
df
# Out:
#              id                                      title   type  \
# 0      ts300399        Five Came Back: The Reference Films   SHOW
# 1       tm84618                                Taxi Driver  MOVIE
# 2      tm154986                                Deliverance  MOVIE
# 3      tm127384            Monty Python And The Holy Grail  MOVIE
# 4      tm120801                            The Dirty Dozen  MOVIE
# ...         ...                                        ...    ...
# 5845  tm1014599                                  Fine Wine  MOVIE
# 5846   tm898842                                C/O Kaadhal  MOVIE
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
# 5849   ts271048         Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# ...

# %% [markdown]
# Step‑5: Convert Dates & Fix Data Types

# %%
print(df.dtypes)
# Out:
# id                       object
# title                    object
# type                     object
# description              object
# release_year              int64
# age_certification        object
# runtime                   int64
# genres                   object
# production_countries     object
# seasons                 float64
# imdb_id                  object
# imdb_score              float64
# imdb_votes              float64
# tmdb_popularity         float64
# tmdb_score              float64
# dtype: object

# %%
df['genres']=df['genres'].astype(str).str.strip("[]").str.replace("'", "").str.replace(",",";")

# %%
df['production_countries'] = df['production_countries'].astype(str).str.strip("[]").str.replace("'", "").str.replace(",", ";")

# %%
print(df[['genres','production_countries']].head(10))
# Out:
#                               genres production_countries
# 0                      documentation                   Us
# 1                       drama; crime                   Us
# 2  drama; action; thriller; european                   Us
# 3            fantasy; action; comedy                   Gb
# 4                        war; action               Gb; Us
# 5                   comedy; european                   Gb
# 6                             comedy                   Gb
# 7            thriller; action; crime                   Us
# 8               crime; drama; action                   Us
# 9             romance; action; drama                   Us

# %%
print(df.dtypes)
# Out:
# id                       object
# title                    object
# type                     object
# description              object
# release_year              int64
# age_certification        object
# runtime                   int64
# genres                   object
# production_countries     object
# seasons                 float64
# imdb_id                  object
# imdb_score              float64
# imdb_votes              float64
# tmdb_popularity         float64
# tmdb_score              float64
# dtype: object

# %% [markdown]
# Save Cleaned Dataset

# %%
df.to_csv(r"C:\Users\ROYAL ENFIELD\Downloads\Netflix_Dataset\titles_cleaned.csv", index=False)
